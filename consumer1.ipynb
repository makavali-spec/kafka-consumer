# %%
import requests

url = "https://endlessmedicalapi1.p.rapidapi.com/UpdateFeature"

querystring = {"name":"<REQUIRED>","value":"<REQUIRED>","SessionID":"first"}

headers = {
	"X-RapidAPI-Key": "01749f85demshb2ca2619cd6f36fp17506bjsnab526ef2683c",
	"X-RapidAPI-Host": "endlessmedicalapi1.p.rapidapi.com"
}

response = requests.post(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'error', 'error': "Couldn't find SessionID."}

# %%
import random
import time
import requests

# OpenWeatherMap API settings
api_key = "6156d68254dfe8638575e65ff5c9d4f2"
weather_api_url = "http://api.openweathermap.org/data/2.5/weather"
city = "New York"
units = "metric"

# Simulated thermostat configuration
num_thermostats = 3

def generate_temperature(weather_data):
    base_temperature = 20.0
    temperature_range = 5.0
    weather_temperature = weather_data["main"]["temp"]
    return base_temperature + random.uniform(-temperature_range, temperature_range) + (weather_temperature - 20.0)

def get_weather_data():
    params = {
        "q": city,
        "units": units,
        "appid": api_key
    }
    try:
        response = requests.get(weather_api_url, params=params)
        response.raise_for_status()  # Raise an exception if request fails
        return response.json()
    except requests.exceptions.RequestException as e:
        print("Failed to fetch weather data:", e)
        return None

while True:
    weather_data = get_weather_data()
    if weather_data:
        for thermostat_id in range(1, num_thermostats + 1):
            temperature = generate_temperature(weather_data)
            # Send temperature data to the central server
            print(f"Thermostat {thermostat_id} - Temperature: {temperature:.2f}°C")
    time.sleep(5)  # Fetch data every 5 minutes
    print('\n')
# Out:
# Thermostat 1 - Temperature: 22.00°C
# Thermostat 2 - Temperature: 20.93°C
# Thermostat 3 - Temperature: 22.32°C
#
#
# Thermostat 1 - Temperature: 26.70°C
# Thermostat 2 - Temperature: 24.47°C
# Thermostat 3 - Temperature: 24.63°C
#
#
# Thermostat 1 - Temperature: 22.28°C
# Thermostat 2 - Temperature: 26.10°C
# Thermostat 3 - Temperature: 23.40°C
#
#
# Thermostat 1 - Temperature: 20.59°C
# Thermostat 2 - Temperature: 27.40°C
# Thermostat 3 - Temperature: 25.19°C
#
#
# Thermostat 1 - Temperature: 25.48°C
# Thermostat 2 - Temperature: 21.85°C
# Thermostat 3 - Temperature: 26.53°C
#
#
# Thermostat 1 - Temperature: 24.69°C
# Thermostat 2 - Temperature: 26.19°C
# Thermostat 3 - Temperature: 20.62°C
#
#
# Thermostat 1 - Temperature: 27.44°C
# Thermostat 2 - Temperature: 22.17°C
# Thermostat 3 - Temperature: 24.47°C
#
#
# Thermostat 1 - Temperature: 23.19°C
# Thermostat 2 - Temperature: 27.28°C
# Thermostat 3 - Temperature: 26.22°C
#
#
# Thermostat 1 - Temperature: 20.17°C
# Thermostat 2 - Temperature: 23.04°C
# Thermostat 3 - Temperature: 21.60°C
#
#
# Thermostat 1 - Temperature: 20.61°C
# Thermostat 2 - Temperature: 22.93°C
# Thermostat 3 - Temperature: 18.92°C
#
#
# Thermostat 1 - Temperature: 26.06°C
# Thermostat 2 - Temperature: 19.01°C
# Thermostat 3 - Temperature: 23.98°C
#
#
# Thermostat 1 - Temperature: 21.90°C
# Thermostat 2 - Temperature: 19.82°C
# Thermostat 3 - Temperature: 20.40°C
#
#
# Thermostat 1 - Temperature: 25.07°C
# Thermostat 2 - Temperature: 27.79°C
# Thermostat 3 - Temperature: 22.70°C
#
#
# Thermostat 1 - Temperature: 22.37°C
# Thermostat 2 - Temperature: 21.43°C
# Thermostat 3 - Temperature: 27.20°C
#
#
# Thermostat 1 - Temperature: 22.41°C
# Thermostat 2 - Temperature: 25.14°C
# Thermostat 3 - Temperature: 22.18°C
#
#
# Thermostat 1 - Temperature: 25.74°C
# Thermostat 2 - Temperature: 26.34°C
# Thermostat 3 - Temperature: 22.03°C
#
#
# Thermostat 1 - Temperature: 24.37°C
# Thermostat 2 - Temperature: 19.88°C
# Thermostat 3 - Temperature: 20.70°C
#
#
# Thermostat 1 - Temperature: 17.93°C
# Thermostat 2 - Temperature: 25.29°C
# Thermostat 3 - Temperature: 27.64°C
#
#
# Thermostat 1 - Temperature: 21.91°C
# Thermostat 2 - Temperature: 21.33°C
# Thermostat 3 - Temperature: 26.17°C
#
#
# Thermostat 1 - Temperature: 23.17°C
# Thermostat 2 - Temperature: 23.75°C
# Thermostat 3 - Temperature: 27.31°C
#
#
# Thermostat 1 - Temperature: 25.53°C
# Thermostat 2 - Temperature: 25.44°C
# Thermostat 3 - Temperature: 26.44°C
#
#
# Thermostat 1 - Temperature: 26.70°C
# Thermostat 2 - Temperature: 24.60°C
# Thermostat 3 - Temperature: 20.55°C
#
#
# Thermostat 1 - Temperature: 22.10°C
# Thermostat 2 - Temperature: 22.67°C
# Thermostat 3 - Temperature: 25.91°C
#
#
# Thermostat 1 - Temperature: 21.58°C
# Thermostat 2 - Temperature: 24.48°C
# Thermostat 3 - Temperature: 18.49°C
#
#
# Thermostat 1 - Temperature: 23.25°C
# Thermostat 2 - Temperature: 20.42°C
# Thermostat 3 - Temperature: 23.18°C
#
#
# Thermostat 1 - Temperature: 26.88°C
# Thermostat 2 - Temperature: 25.49°C
# Thermostat 3 - Temperature: 26.01°C
#
#
# Thermostat 1 - Temperature: 17.90°C
# Thermostat 2 - Temperature: 22.63°C
# Thermostat 3 - Temperature: 25.74°C
#
#
# Thermostat 1 - Temperature: 23.19°C
# Thermostat 2 - Temperature: 19.54°C
# Thermostat 3 - Temperature: 19.72°C
#
#
# Thermostat 1 - Temperature: 23.46°C
# Thermostat 2 - Temperature: 20.55°C
# Thermostat 3 - Temperature: 18.35°C
#
#
# Thermostat 1 - Temperature: 25.25°C
# Thermostat 2 - Temperature: 18.25°C
# Thermostat 3 - Temperature: 27.78°C
#
#
# Thermostat 1 - Temperature: 21.42°C
# Thermostat 2 - Temperature: 18.15°C
# Thermostat 3 - Temperature: 23.47°C
#
#
# Thermostat 1 - Temperature: 22.31°C
# Thermostat 2 - Temperature: 24.39°C
# Thermostat 3 - Temperature: 22.72°C
#
#
# Thermostat 1 - Temperature: 20.09°C
# Thermostat 2 - Temperature: 25.69°C
# Thermostat 3 - Temperature: 24.01°C
#
#
# Thermostat 1 - Temperature: 20.47°C
# Thermostat 2 - Temperature: 25.03°C
# Thermostat 3 - Temperature: 23.27°C
#
#
# Thermostat 1 - Temperature: 23.06°C
# Thermostat 2 - Temperature: 19.41°C
# Thermostat 3 - Temperature: 27.15°C
#
#
# Thermostat 1 - Temperature: 23.15°C
# Thermostat 2 - Temperature: 22.61°C
# Thermostat 3 - Temperature: 19.74°C
#
#
# Thermostat 1 - Temperature: 25.84°C
# Thermostat 2 - Temperature: 21.72°C
# Thermostat 3 - Temperature: 27.81°C
#
#
# Thermostat 1 - Temperature: 25.22°C
# Thermostat 2 - Temperature: 21.41°C
# Thermostat 3 - Temperature: 19.12°C
#
#
# Thermostat 1 - Temperature: 26.04°C
# Thermostat 2 - Temperature: 23.68°C
# Thermostat 3 - Temperature: 27.31°C
#
#
# Thermostat 1 - Temperature: 23.14°C
# Thermostat 2 - Temperature: 27.32°C
# Thermostat 3 - Temperature: 25.73°C
#
#
# Thermostat 1 - Temperature: 21.22°C
# Thermostat 2 - Temperature: 20.55°C
# Thermostat 3 - Temperature: 20.34°C
#
#
# Thermostat 1 - Temperature: 24.23°C
# Thermostat 2 - Temperature: 20.05°C
# Thermostat 3 - Temperature: 19.51°C
#
#
# Thermostat 1 - Temperature: 22.21°C
# Thermostat 2 - Temperature: 20.03°C
# Thermostat 3 - Temperature: 20.81°C
#
#
# Thermostat 1 - Temperature: 18.37°C
# Thermostat 2 - Temperature: 18.30°C
# Thermostat 3 - Temperature: 27.77°C
#
#
# Thermostat 1 - Temperature: 21.54°C
# Thermostat 2 - Temperature: 22.29°C
# Thermostat 3 - Temperature: 21.62°C
#
#
# Thermostat 1 - Temperature: 26.60°C
# Thermostat 2 - Temperature: 18.33°C
# Thermostat 3 - Temperature: 23.73°C
#
#
# Thermostat 1 - Temperature: 25.60°C
# Thermostat 2 - Temperature: 20.89°C
# Thermostat 3 - Temperature: 27.33°C
#
#
# Thermostat 1 - Temperature: 25.81°C
# Thermostat 2 - Temperature: 20.72°C
# Thermostat 3 - Temperature: 26.00°C
#
#
# Thermostat 1 - Temperature: 27.25°C
# Thermostat 2 - Temperature: 26.04°C
# Thermostat 3 - Temperature: 19.81°C
#
#
# Thermostat 1 - Temperature: 21.02°C
# Thermostat 2 - Temperature: 20.38°C
# Thermostat 3 - Temperature: 25.49°C
#
#
# Thermostat 1 - Temperature: 20.96°C
# Thermostat 2 - Temperature: 26.20°C
# Thermostat 3 - Temperature: 18.61°C
#
#
# Thermostat 1 - Temperature: 25.13°C
# Thermostat 2 - Temperature: 26.24°C
# Thermostat 3 - Temperature: 19.20°C
#
#
# Thermostat 1 - Temperature: 27.15°C
# Thermostat 2 - Temperature: 18.30°C
# Thermostat 3 - Temperature: 22.71°C
#
#
# Thermostat 1 - Temperature: 24.88°C
# Thermostat 2 - Temperature: 24.30°C
# Thermostat 3 - Temperature: 25.67°C
#
#
# Thermostat 1 - Temperature: 20.35°C
# Thermostat 2 - Temperature: 22.24°C
# Thermostat 3 - Temperature: 17.99°C
#
#
# Thermostat 1 - Temperature: 24.31°C
# Thermostat 2 - Temperature: 24.48°C
# Thermostat 3 - Temperature: 25.90°C
#
#
# Thermostat 1 - Temperature: 21.27°C
# Thermostat 2 - Temperature: 22.29°C
# Thermostat 3 - Temperature: 24.60°C
#
#
# Thermostat 1 - Temperature: 21.31°C
# Thermostat 2 - Temperature: 22.24°C
# Thermostat 3 - Temperature: 17.91°C
#
#
# Thermostat 1 - Temperature: 25.67°C
# Thermostat 2 - Temperature: 22.57°C
# Thermostat 3 - Temperature: 27.72°C
#
#
# Thermostat 1 - Temperature: 27.38°C
# Thermostat 2 - Temperature: 23.10°C
# Thermostat 3 - Temperature: 23.30°C
#
#
# Thermostat 1 - Temperature: 27.54°C
# Thermostat 2 - Temperature: 24.96°C
# Thermostat 3 - Temperature: 25.54°C
#
#
# Thermostat 1 - Temperature: 18.68°C
# Thermostat 2 - Temperature: 24.99°C
# Thermostat 3 - Temperature: 19.62°C
#
#
# Thermostat 1 - Temperature: 25.45°C
# Thermostat 2 - Temperature: 19.83°C
# Thermostat 3 - Temperature: 20.90°C
#
#
# Thermostat 1 - Temperature: 23.66°C
# Thermostat 2 - Temperature: 27.53°C
# Thermostat 3 - Temperature: 26.94°C
#
#
# Thermostat 1 - Temperature: 23.94°C
# Thermostat 2 - Temperature: 23.51°C
# Thermostat 3 - Temperature: 21.38°C
#
#
# Thermostat 1 - Temperature: 22.53°C
# Thermostat 2 - Temperature: 26.17°C
# Thermostat 3 - Temperature: 24.54°C
#
#
# Thermostat 1 - Temperature: 24.62°C
# Thermostat 2 - Temperature: 26.51°C
# Thermostat 3 - Temperature: 18.74°C
#
#
# Thermostat 1 - Temperature: 27.60°C
# Thermostat 2 - Temperature: 20.87°C
# Thermostat 3 - Temperature: 25.47°C
#
#
# Thermostat 1 - Temperature: 19.70°C
# Thermostat 2 - Temperature: 26.57°C
# Thermostat 3 - Temperature: 22.53°C
#
#
# Thermostat 1 - Temperature: 19.06°C
# Thermostat 2 - Temperature: 20.46°C
# Thermostat 3 - Temperature: 26.23°C
#
#
# Thermostat 1 - Temperature: 24.69°C
# Thermostat 2 - Temperature: 21.98°C
# Thermostat 3 - Temperature: 25.51°C
#
#
# Thermostat 1 - Temperature: 22.60°C
# Thermostat 2 - Temperature: 23.83°C
# Thermostat 3 - Temperature: 22.34°C
#
#
# Thermostat 1 - Temperature: 23.16°C
# Thermostat 2 - Temperature: 20.58°C
# Thermostat 3 - Temperature: 21.36°C
#
#
# Thermostat 1 - Temperature: 18.30°C
# Thermostat 2 - Temperature: 25.39°C
# Thermostat 3 - Temperature: 25.88°C
#
#
# Thermostat 1 - Temperature: 26.91°C
# Thermostat 2 - Temperature: 18.18°C
# Thermostat 3 - Temperature: 24.53°C
# Thermostat 1 - Temperature: 21.71°C
# Thermostat 2 - Temperature: 20.12°C
# Thermostat 3 - Temperature: 20.15°C
#
#
# Thermostat 1 - Temperature: 19.47°C
# Thermostat 2 - Temperature: 26.28°C
# Thermostat 3 - Temperature: 21.32°C
#
#
# Thermostat 1 - Temperature: 21.14°C
# Thermostat 2 - Temperature: 27.82°C
# Thermostat 3 - Temperature: 18.69°C
#
#
# Thermostat 1 - Temperature: 27.86°C
# Thermostat 2 - Temperature: 20.02°C
# Thermostat 3 - Temperature: 27.12°C
#
#
# Thermostat 1 - Temperature: 18.56°C
# Thermostat 2 - Temperature: 23.18°C
# Thermostat 3 - Temperature: 24.96°C
#
#
# Thermostat 1 - Temperature: 19.45°C
# Thermostat 2 - Temperature: 21.99°C
# Thermostat 3 - Temperature: 24.68°C
#
#
# Thermostat 1 - Temperature: 23.72°C
# Thermostat 2 - Temperature: 26.96°C
# Thermostat 3 - Temperature: 26.01°C
#
#
# Thermostat 1 - Temperature: 25.99°C
# Thermostat 2 - Temperature: 19.28°C
# Thermostat 3 - Temperature: 19.45°C
#
#
# Thermostat 1 - Temperature: 20.86°C
# Thermostat 2 - Temperature: 18.81°C
# Thermostat 3 - Temperature: 24.19°C
#
#
# Thermostat 1 - Temperature: 21.17°C
# Thermostat 2 - Temperature: 24.81°C
# Thermostat 3 - Temperature: 25.17°C
#
#
# Thermostat 1 - Temperature: 18.51°C
# Thermostat 2 - Temperature: 23.74°C
# Thermostat 3 - Temperature: 24.45°C
#
#
# Thermostat 1 - Temperature: 26.52°C
# Thermostat 2 - Temperature: 22.23°C
# Thermostat 3 - Temperature: 20.19°C
#
#
# Thermostat 1 - Temperature: 23.64°C
# Thermostat 2 - Temperature: 25.87°C
# Thermostat 3 - Temperature: 23.48°C
#
#
# Thermostat 1 - Temperature: 27.70°C
# Thermostat 2 - Temperature: 24.45°C
# Thermostat 3 - Temperature: 27.64°C
#
#
# Thermostat 1 - Temperature: 27.72°C
# Thermostat 2 - Temperature: 19.89°C
# Thermostat 3 - Temperature: 26.58°C
#
#
# Thermostat 1 - Temperature: 26.40°C
# Thermostat 2 - Temperature: 20.77°C
# Thermostat 3 - Temperature: 25.40°C
#
#
# Thermostat 1 - Temperature: 27.76°C
# Thermostat 2 - Temperature: 25.47°C
# Thermostat 3 - Temperature: 23.02°C
#
#
# Thermostat 1 - Temperature: 26.57°C
# Thermostat 2 - Temperature: 19.23°C
# Thermostat 3 - Temperature: 21.94°C
#
#
# Thermostat 1 - Temperature: 26.62°C
# Thermostat 2 - Temperature: 21.37°C
# Thermostat 3 - Temperature: 24.11°C
#
#
# Thermostat 1 - Temperature: 26.52°C
# Thermostat 2 - Temperature: 26.40°C
# Thermostat 3 - Temperature: 27.01°C
#
#
# Thermostat 1 - Temperature: 21.02°C
# Thermostat 2 - Temperature: 19.97°C
# Thermostat 3 - Temperature: 18.43°C
#
#
# Thermostat 1 - Temperature: 21.40°C
# Thermostat 2 - Temperature: 23.86°C
# Thermostat 3 - Temperature: 18.70°C
#
#
# Thermostat 1 - Temperature: 27.14°C
# Thermostat 2 - Temperature: 27.09°C
# Thermostat 3 - Temperature: 20.42°C
#
#
# Thermostat 1 - Temperature: 21.32°C
# Thermostat 2 - Temperature: 19.63°C
# Thermostat 3 - Temperature: 26.90°C
#
#
# Thermostat 1 - Temperature: 25.26°C
# Thermostat 2 - Temperature: 20.87°C
# Thermostat 3 - Temperature: 24.82°C
#
#
# Thermostat 1 - Temperature: 26.24°C
# Thermostat 2 - Temperature: 19.79°C
# Thermostat 3 - Temperature: 23.50°C
#
#
# Thermostat 1 - Temperature: 25.41°C
# Thermostat 2 - Temperature: 25.54°C
# Thermostat 3 - Temperature: 19.44°C
#
#
# Thermostat 1 - Temperature: 19.16°C
# Thermostat 2 - Temperature: 24.64°C
# Thermostat 3 - Temperature: 23.34°C
#
#
# Thermostat 1 - Temperature: 23.49°C
# Thermostat 2 - Temperature: 24.47°C
# Thermostat 3 - Temperature: 23.82°C
#
#
# Thermostat 1 - Temperature: 18.25°C
# Thermostat 2 - Temperature: 23.58°C
# Thermostat 3 - Temperature: 22.47°C
#
#
# Thermostat 1 - Temperature: 20.39°C
# Thermostat 2 - Temperature: 19.43°C
# Thermostat 3 - Temperature: 24.00°C
#
#
# Thermostat 1 - Temperature: 23.66°C
# Thermostat 2 - Temperature: 23.27°C
# Thermostat 3 - Temperature: 27.04°C
#
#
# Thermostat 1 - Temperature: 26.43°C
# Thermostat 2 - Temperature: 19.00°C
# Thermostat 3 - Temperature: 22.67°C
#
#
# Thermostat 1 - Temperature: 19.21°C
# Thermostat 2 - Temperature: 18.44°C
# Thermostat 3 - Temperature: 20.59°C
#
#
# Thermostat 1 - Temperature: 27.26°C
# Thermostat 2 - Temperature: 22.36°C
# Thermostat 3 - Temperature: 22.12°C
#
#
# Thermostat 1 - Temperature: 23.63°C
# Thermostat 2 - Temperature: 24.02°C
# Thermostat 3 - Temperature: 18.95°C
#
#
# Thermostat 1 - Temperature: 26.52°C
# Thermostat 2 - Temperature: 18.49°C
# Thermostat 3 - Temperature: 25.71°C
#
#
# Thermostat 1 - Temperature: 26.42°C
# Thermostat 2 - Temperature: 18.95°C
# Thermostat 3 - Temperature: 19.98°C
#
#
# Thermostat 1 - Temperature: 23.99°C
# Thermostat 2 - Temperature: 19.70°C
# Thermostat 3 - Temperature: 22.81°C
#
#
# Thermostat 1 - Temperature: 21.77°C
# Thermostat 2 - Temperature: 19.57°C
# Thermostat 3 - Temperature: 19.18°C
#
#
# Thermostat 1 - Temperature: 18.76°C
# Thermostat 2 - Temperature: 23.52°C
# Thermostat 3 - Temperature: 22.52°C
#
#
# Thermostat 1 - Temperature: 22.40°C
# Thermostat 2 - Temperature: 21.71°C
# Thermostat 3 - Temperature: 26.86°C
#
#
# Thermostat 1 - Temperature: 24.56°C
# Thermostat 2 - Temperature: 20.42°C
# Thermostat 3 - Temperature: 22.22°C
#
#
# Thermostat 1 - Temperature: 20.80°C
# Thermostat 2 - Temperature: 25.04°C
# Thermostat 3 - Temperature: 27.34°C
#
#
# Thermostat 1 - Temperature: 21.71°C
# Thermostat 2 - Temperature: 23.16°C
# Thermostat 3 - Temperature: 20.93°C
#
#
# Thermostat 1 - Temperature: 21.60°C
# Thermostat 2 - Temperature: 23.88°C
# Thermostat 3 - Temperature: 22.55°C
#
#
# Thermostat 1 - Temperature: 24.22°C
# Thermostat 2 - Temperature: 27.07°C
# Thermostat 3 - Temperature: 22.98°C
#
#
# Thermostat 1 - Temperature: 25.05°C
# Thermostat 2 - Temperature: 20.58°C
# Thermostat 3 - Temperature: 25.33°C
#
#
# Thermostat 1 - Temperature: 24.92°C
# Thermostat 2 - Temperature: 25.76°C
# Thermostat 3 - Temperature: 17.96°C
#
#
# Thermostat 1 - Temperature: 20.49°C
# Thermostat 2 - Temperature: 26.95°C
# Thermostat 3 - Temperature: 18.13°C
#
#
# Thermostat 1 - Temperature: 19.04°C
# Thermostat 2 - Temperature: 20.44°C
# Thermostat 3 - Temperature: 23.10°C
#
#
# Thermostat 1 - Temperature: 20.84°C
# Thermostat 2 - Temperature: 20.37°C
# Thermostat 3 - Temperature: 21.22°C
#
#
# Thermostat 1 - Temperature: 26.95°C
# Thermostat 2 - Temperature: 18.80°C
# Thermostat 3 - Temperature: 24.07°C
#
#
# Thermostat 1 - Temperature: 20.31°C
# Thermostat 2 - Temperature: 18.89°C
# Thermostat 3 - Temperature: 19.81°C
#
#
# Thermostat 1 - Temperature: 25.88°C
# Thermostat 2 - Temperature: 27.43°C
# Thermostat 3 - Temperature: 26.22°C
#
#
# Thermostat 1 - Temperature: 24.82°C
# Thermostat 2 - Temperature: 22.10°C
# Thermostat 3 - Temperature: 25.78°C
#
#
# Thermostat 1 - Temperature: 19.93°C
# Thermostat 2 - Temperature: 24.61°C
# Thermostat 3 - Temperature: 24.28°C
#
#
# Thermostat 1 - Temperature: 18.44°C
# Thermostat 2 - Temperature: 27.65°C
# Thermostat 3 - Temperature: 23.07°C
#
#
# Thermostat 1 - Temperature: 22.46°C
# Thermostat 2 - Temperature: 22.36°C
# Thermostat 3 - Temperature: 22.13°C
#
#
# Thermostat 1 - Temperature: 25.62°C
# Thermostat 2 - Temperature: 24.56°C
# Thermostat 3 - Temperature: 27.42°C
#
#
# Thermostat 1 - Temperature: 27.53°C
# Thermostat 2 - Temperature: 22.71°C
# Thermostat 3 - Temperature: 27.00°C
#
#
# Thermostat 1 - Temperature: 23.09°C
# Thermostat 2 - Temperature: 27.59°C
# Thermostat 3 - Temperature: 18.57°C
#
#
# Thermostat 1 - Temperature: 19.31°C
# Thermostat 2 - Temperature: 19.39°C
# Thermostat 3 - Temperature: 26.32°C
#
#
# Thermostat 1 - Temperature: 26.94°C
# Thermostat 2 - Temperature: 20.36°C
# Thermostat 3 - Temperature: 18.96°C
#
#
# Thermostat 1 - Temperature: 27.54°C
# Thermostat 2 - Temperature: 26.32°C
# Thermostat 3 - Temperature: 25.21°C
#
#
# Thermostat 1 - Temperature: 26.38°C
# Thermostat 2 - Temperature: 23.58°C
# Thermostat 3 - Temperature: 23.46°C
#
#
# Thermostat 1 - Temperature: 19.65°C
# Thermostat 2 - Temperature: 25.38°C
# Thermostat 3 - Temperature: 18.67°C
#
#
# Thermostat 1 - Temperature: 25.07°C
# Thermostat 2 - Temperature: 27.41°C
# Thermostat 3 - Temperature: 18.37°C
#
#
# Thermostat 1 - Temperature: 23.59°C
# Thermostat 2 - Temperature: 25.81°C
# Thermostat 3 - Temperature: 22.96°C
#
#
# Thermostat 1 - Temperature: 23.08°C
# Thermostat 2 - Temperature: 27.55°C
# Thermostat 3 - Temperature: 20.89°C
#
#
# Thermostat 1 - Temperature: 27.10°C
# Thermostat 2 - Temperature: 17.75°C
# Thermostat 3 - Temperature: 21.29°C
#
#
# Thermostat 1 - Temperature: 27.49°C
# Thermostat 2 - Temperature: 27.63°C
# Thermostat 3 - Temperature: 22.74°C
#
#
# Thermostat 1 - Temperature: 22.92°C
# Thermostat 2 - Temperature: 23.95°C
# Thermostat 3 - Temperature: 17.95°C
#
#
# Thermostat 1 - Temperature: 21.52°C
# Thermostat 2 - Temperature: 23.18°C
# Thermostat 3 - Temperature: 24.69°C
#
#
# Thermostat 1 - Temperature: 19.57°C
# Thermostat 2 - Temperature: 26.38°C
# Thermostat 3 - Temperature: 19.39°C
# Thermostat 1 - Temperature: 18.58°C
# Thermostat 2 - Temperature: 26.12°C
# Thermostat 3 - Temperature: 21.04°C
#
#
# Thermostat 1 - Temperature: 23.73°C
# Thermostat 2 - Temperature: 24.03°C
# Thermostat 3 - Temperature: 25.88°C
#
#
# Thermostat 1 - Temperature: 18.35°C
# Thermostat 2 - Temperature: 24.82°C
# Thermostat 3 - Temperature: 24.78°C
#
#
# Thermostat 1 - Temperature: 18.21°C
# Thermostat 2 - Temperature: 21.04°C
# Thermostat 3 - Temperature: 18.70°C
#
#
# Thermostat 1 - Temperature: 19.61°C
# Thermostat 2 - Temperature: 17.91°C
# Thermostat 3 - Temperature: 25.39°C
#
#
# Thermostat 1 - Temperature: 21.05°C
# Thermostat 2 - Temperature: 22.81°C
# Thermostat 3 - Temperature: 21.81°C
#
#
# Thermostat 1 - Temperature: 25.15°C
# Thermostat 2 - Temperature: 27.04°C
# Thermostat 3 - Temperature: 21.66°C
#
#
# Thermostat 1 - Temperature: 22.26°C
# Thermostat 2 - Temperature: 23.79°C
# Thermostat 3 - Temperature: 24.97°C
#
#
# Thermostat 1 - Temperature: 22.75°C
# Thermostat 2 - Temperature: 21.83°C
# Thermostat 3 - Temperature: 20.75°C
#
#
# Thermostat 1 - Temperature: 27.51°C
# Thermostat 2 - Temperature: 17.82°C
# Thermostat 3 - Temperature: 27.18°C
#
#
# Thermostat 1 - Temperature: 25.49°C
# Thermostat 2 - Temperature: 19.19°C
# Thermostat 3 - Temperature: 26.70°C
#
#
# Thermostat 1 - Temperature: 22.06°C
# Thermostat 2 - Temperature: 18.07°C
# Thermostat 3 - Temperature: 24.42°C
#
#
# Thermostat 1 - Temperature: 26.22°C
# Thermostat 2 - Temperature: 21.07°C
# Thermostat 3 - Temperature: 25.98°C
#
#
# Thermostat 1 - Temperature: 22.76°C
# Thermostat 2 - Temperature: 26.55°C
# Thermostat 3 - Temperature: 20.30°C
#
#
# Thermostat 1 - Temperature: 18.55°C
# Thermostat 2 - Temperature: 24.63°C
# Thermostat 3 - Temperature: 26.25°C
#
#
# Thermostat 1 - Temperature: 17.78°C
# Thermostat 2 - Temperature: 21.09°C
# Thermostat 3 - Temperature: 19.36°C
#
#
# Thermostat 1 - Temperature: 25.01°C
# Thermostat 2 - Temperature: 24.24°C
# Thermostat 3 - Temperature: 19.45°C
#
#
# Thermostat 1 - Temperature: 24.99°C
# Thermostat 2 - Temperature: 27.67°C
# Thermostat 3 - Temperature: 19.29°C
#
#
# Thermostat 1 - Temperature: 18.55°C
# Thermostat 2 - Temperature: 20.07°C
# Thermostat 3 - Temperature: 19.14°C
#
#
# Thermostat 1 - Temperature: 21.83°C
# Thermostat 2 - Temperature: 19.12°C
# Thermostat 3 - Temperature: 25.68°C
#
#
# Thermostat 1 - Temperature: 24.72°C
# Thermostat 2 - Temperature: 27.18°C
# Thermostat 3 - Temperature: 24.69°C
#
#
# Thermostat 1 - Temperature: 25.33°C
# Thermostat 2 - Temperature: 26.09°C
# Thermostat 3 - Temperature: 19.31°C
#
#
# Thermostat 1 - Temperature: 18.04°C
# Thermostat 2 - Temperature: 23.78°C
# Thermostat 3 - Temperature: 19.03°C
#
#
# Thermostat 1 - Temperature: 18.05°C
# Thermostat 2 - Temperature: 20.93°C
# Thermostat 3 - Temperature: 18.21°C
#
#
# Thermostat 1 - Temperature: 25.68°C
# Thermostat 2 - Temperature: 18.34°C
# Thermostat 3 - Temperature: 21.43°C
#
#
# Thermostat 1 - Temperature: 21.23°C
# Thermostat 2 - Temperature: 22.65°C
# Thermostat 3 - Temperature: 26.91°C
#
#
# Thermostat 1 - Temperature: 22.19°C
# Thermostat 2 - Temperature: 18.68°C
# Thermostat 3 - Temperature: 19.95°C
#
#
# Thermostat 1 - Temperature: 26.47°C
# Thermostat 2 - Temperature: 22.24°C
# Thermostat 3 - Temperature: 22.88°C
#
#
# Thermostat 1 - Temperature: 20.92°C
# Thermostat 2 - Temperature: 18.09°C
# Thermostat 3 - Temperature: 19.30°C
#
#
# Thermostat 1 - Temperature: 26.23°C
# Thermostat 2 - Temperature: 25.76°C
# Thermostat 3 - Temperature: 18.71°C
#
#
# Thermostat 1 - Temperature: 24.70°C
# Thermostat 2 - Temperature: 25.53°C
# Thermostat 3 - Temperature: 26.83°C
#
#
# Thermostat 1 - Temperature: 23.77°C
# Thermostat 2 - Temperature: 21.08°C
# Thermostat 3 - Temperature: 26.31°C
#
#
# Thermostat 1 - Temperature: 21.46°C
# Thermostat 2 - Temperature: 18.80°C
# Thermostat 3 - Temperature: 20.65°C
#
#
# Thermostat 1 - Temperature: 21.68°C
# Thermostat 2 - Temperature: 25.69°C
# Thermostat 3 - Temperature: 25.87°C
#
#
# Thermostat 1 - Temperature: 18.35°C
# Thermostat 2 - Temperature: 21.02°C
# Thermostat 3 - Temperature: 23.46°C
#
#
# Thermostat 1 - Temperature: 24.27°C
# Thermostat 2 - Temperature: 20.29°C
# Thermostat 3 - Temperature: 26.55°C
#
#
# Thermostat 1 - Temperature: 21.98°C
# Thermostat 2 - Temperature: 23.24°C
# Thermostat 3 - Temperature: 26.87°C
#
#
# Thermostat 1 - Temperature: 23.38°C
# Thermostat 2 - Temperature: 20.93°C
# Thermostat 3 - Temperature: 24.59°C
#
#
# Thermostat 1 - Temperature: 19.54°C
# Thermostat 2 - Temperature: 23.64°C
# Thermostat 3 - Temperature: 19.12°C
#
#
# Thermostat 1 - Temperature: 27.05°C
# Thermostat 2 - Temperature: 26.42°C
# Thermostat 3 - Temperature: 22.58°C
#
#
# Thermostat 1 - Temperature: 20.99°C
# Thermostat 2 - Temperature: 18.47°C
# Thermostat 3 - Temperature: 20.18°C
#
#
# Thermostat 1 - Temperature: 19.99°C
# Thermostat 2 - Temperature: 20.68°C
# Thermostat 3 - Temperature: 27.65°C
#
#
# Thermostat 1 - Temperature: 19.56°C
# Thermostat 2 - Temperature: 27.18°C
# Thermostat 3 - Temperature: 24.33°C
#
#
# Thermostat 1 - Temperature: 23.65°C
# Thermostat 2 - Temperature: 24.34°C
# Thermostat 3 - Temperature: 26.93°C
#
#
# Thermostat 1 - Temperature: 21.74°C
# Thermostat 2 - Temperature: 20.43°C
# Thermostat 3 - Temperature: 23.52°C
#
#
# Thermostat 1 - Temperature: 21.85°C
# Thermostat 2 - Temperature: 26.34°C
# Thermostat 3 - Temperature: 20.22°C
#
#
# Thermostat 1 - Temperature: 22.64°C
# Thermostat 2 - Temperature: 23.49°C
# Thermostat 3 - Temperature: 22.74°C
#
#
# Thermostat 1 - Temperature: 27.24°C
# Thermostat 2 - Temperature: 25.24°C
# Thermostat 3 - Temperature: 24.69°C
#
#
# Thermostat 1 - Temperature: 21.92°C
# Thermostat 2 - Temperature: 20.66°C
# Thermostat 3 - Temperature: 19.07°C
#
#
# Thermostat 1 - Temperature: 23.64°C
# Thermostat 2 - Temperature: 18.97°C
# Thermostat 3 - Temperature: 24.36°C
#
#
# Thermostat 1 - Temperature: 23.64°C
# Thermostat 2 - Temperature: 19.49°C
# Thermostat 3 - Temperature: 25.78°C
#
#
# Thermostat 1 - Temperature: 23.23°C
# Thermostat 2 - Temperature: 20.57°C
# Thermostat 3 - Temperature: 20.29°C
#
#
# Thermostat 1 - Temperature: 23.04°C
# Thermostat 2 - Temperature: 22.34°C
# Thermostat 3 - Temperature: 18.15°C
#
#
# Thermostat 1 - Temperature: 27.22°C
# Thermostat 2 - Temperature: 18.51°C
# Thermostat 3 - Temperature: 20.66°C
#
#
# Thermostat 1 - Temperature: 19.74°C
# Thermostat 2 - Temperature: 17.96°C
# Thermostat 3 - Temperature: 27.21°C
#
#
# Thermostat 1 - Temperature: 25.71°C
# Thermostat 2 - Temperature: 19.17°C
# Thermostat 3 - Temperature: 26.49°C
#
#
# Thermostat 1 - Temperature: 19.66°C
# Thermostat 2 - Temperature: 22.79°C
# Thermostat 3 - Temperature: 26.82°C
#
#
# Thermostat 1 - Temperature: 24.47°C
# Thermostat 2 - Temperature: 17.95°C
# Thermostat 3 - Temperature: 25.96°C
#
#
# Thermostat 1 - Temperature: 21.67°C
# Thermostat 2 - Temperature: 24.30°C
# Thermostat 3 - Temperature: 21.32°C
#
#
# Thermostat 1 - Temperature: 22.05°C
# Thermostat 2 - Temperature: 26.27°C
# Thermostat 3 - Temperature: 17.70°C
#
#
# Thermostat 1 - Temperature: 24.33°C
# Thermostat 2 - Temperature: 24.74°C
# Thermostat 3 - Temperature: 21.32°C
#
#
# Thermostat 1 - Temperature: 19.88°C
# Thermostat 2 - Temperature: 26.32°C
# Thermostat 3 - Temperature: 24.03°C
#
#
# Thermostat 1 - Temperature: 17.63°C
# Thermostat 2 - Temperature: 19.67°C
# Thermostat 3 - Temperature: 17.87°C
#
#
# Thermostat 1 - Temperature: 20.81°C
# Thermostat 2 - Temperature: 25.59°C
# Thermostat 3 - Temperature: 19.31°C
#
#
# Thermostat 1 - Temperature: 25.51°C
# Thermostat 2 - Temperature: 21.66°C
# Thermostat 3 - Temperature: 18.32°C
#
#
# Thermostat 1 - Temperature: 22.33°C
# Thermostat 2 - Temperature: 22.77°C
# Thermostat 3 - Temperature: 19.08°C
#
#
# Thermostat 1 - Temperature: 26.37°C
# Thermostat 2 - Temperature: 26.71°C
# Thermostat 3 - Temperature: 26.27°C
#
#
# Thermostat 1 - Temperature: 26.69°C
# Thermostat 2 - Temperature: 23.07°C
# Thermostat 3 - Temperature: 18.78°C
#
#
# Thermostat 1 - Temperature: 20.72°C
# Thermostat 2 - Temperature: 27.44°C
# Thermostat 3 - Temperature: 25.32°C
#
#
# Thermostat 1 - Temperature: 18.53°C
# Thermostat 2 - Temperature: 26.09°C
# Thermostat 3 - Temperature: 25.42°C
#
#
# Thermostat 1 - Temperature: 23.86°C
# Thermostat 2 - Temperature: 21.92°C
# Thermostat 3 - Temperature: 18.57°C
#
#
# Thermostat 1 - Temperature: 18.99°C
# Thermostat 2 - Temperature: 22.06°C
# Thermostat 3 - Temperature: 20.37°C
#
#
# Thermostat 1 - Temperature: 24.05°C
# Thermostat 2 - Temperature: 21.45°C
# Thermostat 3 - Temperature: 17.79°C
#
#
# Thermostat 1 - Temperature: 25.76°C
# Thermostat 2 - Temperature: 18.16°C
# Thermostat 3 - Temperature: 22.95°C
#
#
# Thermostat 1 - Temperature: 19.36°C
# Thermostat 2 - Temperature: 18.44°C
# Thermostat 3 - Temperature: 17.63°C
# Thermostat 1 - Temperature: 25.35°C
# Thermostat 2 - Temperature: 23.99°C
# Thermostat 3 - Temperature: 21.34°C
#
#
# Thermostat 1 - Temperature: 27.41°C
# Thermostat 2 - Temperature: 21.60°C
# Thermostat 3 - Temperature: 20.36°C
#
#
# Thermostat 1 - Temperature: 21.77°C
# Thermostat 2 - Temperature: 25.77°C
# Thermostat 3 - Temperature: 24.65°C
#
#
# Thermostat 1 - Temperature: 26.39°C
# Thermostat 2 - Temperature: 25.55°C
# Thermostat 3 - Temperature: 18.70°C
#
#
# Thermostat 1 - Temperature: 22.97°C
# Thermostat 2 - Temperature: 25.64°C
# Thermostat 3 - Temperature: 26.73°C
#
#
# Thermostat 1 - Temperature: 25.37°C
# Thermostat 2 - Temperature: 20.95°C
# Thermostat 3 - Temperature: 17.75°C
#
#
# Thermostat 1 - Temperature: 18.96°C
# Thermostat 2 - Temperature: 19.79°C
# Thermostat 3 - Temperature: 23.80°C
#
#
# Thermostat 1 - Temperature: 21.15°C
# Thermostat 2 - Temperature: 23.61°C
# Thermostat 3 - Temperature: 26.79°C
#
#
# Thermostat 1 - Temperature: 27.32°C
# Thermostat 2 - Temperature: 23.80°C
# Thermostat 3 - Temperature: 27.47°C
#
#
# Thermostat 1 - Temperature: 20.24°C
# Thermostat 2 - Temperature: 21.07°C
# Thermostat 3 - Temperature: 25.27°C
#
#
# Thermostat 1 - Temperature: 19.33°C
# Thermostat 2 - Temperature: 22.89°C
# Thermostat 3 - Temperature: 27.35°C
#
#
# Thermostat 1 - Temperature: 20.01°C
# Thermostat 2 - Temperature: 22.14°C
# Thermostat 3 - Temperature: 19.91°C
#
#
# Thermostat 1 - Temperature: 23.81°C
# Thermostat 2 - Temperature: 22.29°C
# Thermostat 3 - Temperature: 17.65°C
#
#
# Thermostat 1 - Temperature: 23.32°C
# Thermostat 2 - Temperature: 24.56°C
# Thermostat 3 - Temperature: 26.85°C
#
#
# Thermostat 1 - Temperature: 18.60°C
# Thermostat 2 - Temperature: 23.44°C
# Thermostat 3 - Temperature: 20.44°C
#
#
# Thermostat 1 - Temperature: 22.51°C
# Thermostat 2 - Temperature: 20.75°C
# Thermostat 3 - Temperature: 25.14°C
#
#
# Thermostat 1 - Temperature: 23.79°C
# Thermostat 2 - Temperature: 22.82°C
# Thermostat 3 - Temperature: 22.62°C
#
#
# Thermostat 1 - Temperature: 24.63°C
# Thermostat 2 - Temperature: 23.54°C
# Thermostat 3 - Temperature: 21.18°C
#
#
# Thermostat 1 - Temperature: 19.38°C
# Thermostat 2 - Temperature: 25.08°C
# Thermostat 3 - Temperature: 21.22°C
#
#
# Thermostat 1 - Temperature: 19.24°C
# Thermostat 2 - Temperature: 26.39°C
# Thermostat 3 - Temperature: 27.12°C
#
#
# Thermostat 1 - Temperature: 27.39°C
# Thermostat 2 - Temperature: 22.21°C
# Thermostat 3 - Temperature: 20.39°C
#
#
# Thermostat 1 - Temperature: 21.98°C
# Thermostat 2 - Temperature: 23.39°C
# Thermostat 3 - Temperature: 19.02°C
#
#
# Thermostat 1 - Temperature: 22.89°C
# Thermostat 2 - Temperature: 18.35°C
# Thermostat 3 - Temperature: 17.65°C
#
#
# Thermostat 1 - Temperature: 19.62°C
# Thermostat 2 - Temperature: 20.39°C
# Thermostat 3 - Temperature: 21.27°C
#
#
# Thermostat 1 - Temperature: 24.00°C
# Thermostat 2 - Temperature: 24.31°C
# Thermostat 3 - Temperature: 23.29°C
#
#
# Thermostat 1 - Temperature: 25.03°C
# Thermostat 2 - Temperature: 21.98°C
# Thermostat 3 - Temperature: 17.76°C
#
#
# Thermostat 1 - Temperature: 19.44°C
# Thermostat 2 - Temperature: 18.60°C
# Thermostat 3 - Temperature: 19.27°C
#
#
# Thermostat 1 - Temperature: 27.00°C
# Thermostat 2 - Temperature: 22.98°C
# Thermostat 3 - Temperature: 23.81°C
#
#
# Thermostat 1 - Temperature: 18.22°C
# Thermostat 2 - Temperature: 17.81°C
# Thermostat 3 - Temperature: 25.03°C
#
#
# Thermostat 1 - Temperature: 25.69°C
# Thermostat 2 - Temperature: 19.69°C
# Thermostat 3 - Temperature: 27.00°C
#
#
# Thermostat 1 - Temperature: 20.62°C
# Thermostat 2 - Temperature: 23.63°C
# Thermostat 3 - Temperature: 25.53°C
#
#
# Thermostat 1 - Temperature: 22.54°C
# Thermostat 2 - Temperature: 23.94°C
# Thermostat 3 - Temperature: 23.58°C
#
#
# Thermostat 1 - Temperature: 27.01°C
# Thermostat 2 - Temperature: 22.14°C
# Thermostat 3 - Temperature: 19.61°C
#
#
# Thermostat 1 - Temperature: 25.10°C
# Thermostat 2 - Temperature: 19.28°C
# Thermostat 3 - Temperature: 18.67°C
#
#
# Thermostat 1 - Temperature: 23.14°C
# Thermostat 2 - Temperature: 22.01°C
# Thermostat 3 - Temperature: 20.39°C
#
#
# Thermostat 1 - Temperature: 20.16°C
# Thermostat 2 - Temperature: 26.83°C
# Thermostat 3 - Temperature: 20.57°C
#
#
# Thermostat 1 - Temperature: 25.65°C
# Thermostat 2 - Temperature: 20.86°C
# Thermostat 3 - Temperature: 17.61°C
#
#
# Thermostat 1 - Temperature: 18.08°C
# Thermostat 2 - Temperature: 20.05°C
# Thermostat 3 - Temperature: 26.98°C
#
#
# Thermostat 1 - Temperature: 24.15°C
# Thermostat 2 - Temperature: 22.95°C
# Thermostat 3 - Temperature: 19.30°C
#
#
# Thermostat 1 - Temperature: 26.91°C
# Thermostat 2 - Temperature: 24.09°C
# Thermostat 3 - Temperature: 21.28°C
#
#
# Thermostat 1 - Temperature: 19.87°C
# Thermostat 2 - Temperature: 27.18°C
# Thermostat 3 - Temperature: 24.74°C
#
#
# Thermostat 1 - Temperature: 27.53°C
# Thermostat 2 - Temperature: 18.95°C
# Thermostat 3 - Temperature: 22.56°C
#
#
# Thermostat 1 - Temperature: 25.56°C
# Thermostat 2 - Temperature: 22.81°C
# Thermostat 3 - Temperature: 26.57°C
#
#
# Thermostat 1 - Temperature: 22.59°C
# Thermostat 2 - Temperature: 23.95°C
# Thermostat 3 - Temperature: 20.55°C
#
#
# Thermostat 1 - Temperature: 23.54°C
# Thermostat 2 - Temperature: 21.42°C
# Thermostat 3 - Temperature: 21.48°C
#
#
# Thermostat 1 - Temperature: 18.56°C
# Thermostat 2 - Temperature: 19.33°C
# Thermostat 3 - Temperature: 20.38°C
#
#
# Thermostat 1 - Temperature: 20.51°C
# Thermostat 2 - Temperature: 23.41°C
# Thermostat 3 - Temperature: 20.77°C
#
#
# Thermostat 1 - Temperature: 20.01°C
# Thermostat 2 - Temperature: 18.03°C
# Thermostat 3 - Temperature: 17.82°C
#
#
# Thermostat 1 - Temperature: 23.95°C
# Thermostat 2 - Temperature: 19.79°C
# Thermostat 3 - Temperature: 27.09°C
#
#
# Thermostat 1 - Temperature: 23.04°C
# Thermostat 2 - Temperature: 23.24°C
# Thermostat 3 - Temperature: 23.73°C
#
#
# Thermostat 1 - Temperature: 24.92°C
# Thermostat 2 - Temperature: 22.16°C
# Thermostat 3 - Temperature: 21.91°C
#
#
# Thermostat 1 - Temperature: 25.33°C
# Thermostat 2 - Temperature: 20.02°C
# Thermostat 3 - Temperature: 22.33°C
#
#
# Thermostat 1 - Temperature: 17.61°C
# Thermostat 2 - Temperature: 27.27°C
# Thermostat 3 - Temperature: 24.49°C
#
#
# Thermostat 1 - Temperature: 26.23°C
# Thermostat 2 - Temperature: 21.66°C
# Thermostat 3 - Temperature: 20.33°C
#
#
# Thermostat 1 - Temperature: 25.90°C
# Thermostat 2 - Temperature: 27.11°C
# Thermostat 3 - Temperature: 24.69°C
#
#
# Thermostat 1 - Temperature: 21.34°C
# Thermostat 2 - Temperature: 22.28°C
# Thermostat 3 - Temperature: 22.45°C
#
#
# Thermostat 1 - Temperature: 20.86°C
# Thermostat 2 - Temperature: 17.78°C
# Thermostat 3 - Temperature: 21.46°C
#
#
# Thermostat 1 - Temperature: 22.48°C
# Thermostat 2 - Temperature: 21.29°C
# Thermostat 3 - Temperature: 23.53°C
#
#
# Thermostat 1 - Temperature: 21.25°C
# Thermostat 2 - Temperature: 21.56°C
# Thermostat 3 - Temperature: 18.90°C
#
#
# Thermostat 1 - Temperature: 25.30°C
# Thermostat 2 - Temperature: 20.27°C
# Thermostat 3 - Temperature: 22.80°C
#
#
# Thermostat 1 - Temperature: 19.56°C
# Thermostat 2 - Temperature: 23.66°C
# Thermostat 3 - Temperature: 20.67°C
#
#
# Thermostat 1 - Temperature: 19.79°C
# Thermostat 2 - Temperature: 21.80°C
# Thermostat 3 - Temperature: 23.03°C
#
#
# Thermostat 1 - Temperature: 26.38°C
# Thermostat 2 - Temperature: 26.93°C
# Thermostat 3 - Temperature: 22.43°C
#
#
# Thermostat 1 - Temperature: 25.98°C
# Thermostat 2 - Temperature: 26.09°C
# Thermostat 3 - Temperature: 25.03°C
#
#
# Thermostat 1 - Temperature: 23.47°C
# Thermostat 2 - Temperature: 18.79°C
# Thermostat 3 - Temperature: 23.46°C
#
#
# Thermostat 1 - Temperature: 27.33°C
# Thermostat 2 - Temperature: 24.08°C
# Thermostat 3 - Temperature: 27.20°C
#
#
# Thermostat 1 - Temperature: 25.36°C
# Thermostat 2 - Temperature: 24.30°C
# Thermostat 3 - Temperature: 18.88°C
#
#
# Thermostat 1 - Temperature: 24.09°C
# Thermostat 2 - Temperature: 23.44°C
# Thermostat 3 - Temperature: 19.57°C
#
#
# Thermostat 1 - Temperature: 19.16°C
# Thermostat 2 - Temperature: 25.93°C
# Thermostat 3 - Temperature: 20.36°C
#
#
# Thermostat 1 - Temperature: 22.89°C
# Thermostat 2 - Temperature: 21.69°C
# Thermostat 3 - Temperature: 22.74°C
#
#
# Thermostat 1 - Temperature: 17.94°C
# Thermostat 2 - Temperature: 20.70°C
# Thermostat 3 - Temperature: 22.22°C
#
#
# Thermostat 1 - Temperature: 25.86°C
# Thermostat 2 - Temperature: 24.75°C
# Thermostat 3 - Temperature: 22.70°C
#
#
# Thermostat 1 - Temperature: 25.11°C
# Thermostat 2 - Temperature: 26.20°C
# Thermostat 3 - Temperature: 20.35°C
#
#
# Thermostat 1 - Temperature: 19.17°C
# Thermostat 2 - Temperature: 18.65°C
# Thermostat 3 - Temperature: 26.58°C
#
#
# Thermostat 1 - Temperature: 18.57°C
# Thermostat 2 - Temperature: 24.48°C
# Thermostat 3 - Temperature: 17.93°C
# Thermostat 1 - Temperature: 20.19°C
# Thermostat 2 - Temperature: 18.07°C
# Thermostat 3 - Temperature: 24.35°C
#
#
# Thermostat 1 - Temperature: 20.84°C
# Thermostat 2 - Temperature: 26.17°C
# Thermostat 3 - Temperature: 18.54°C
#
#
# Thermostat 1 - Temperature: 25.17°C
# Thermostat 2 - Temperature: 24.76°C
# Thermostat 3 - Temperature: 23.63°C
#
#
# Thermostat 1 - Temperature: 21.23°C
# Thermostat 2 - Temperature: 22.49°C
# Thermostat 3 - Temperature: 25.29°C
#
#
# Thermostat 1 - Temperature: 18.61°C
# Thermostat 2 - Temperature: 22.25°C
# Thermostat 3 - Temperature: 21.11°C
#
#
# Thermostat 1 - Temperature: 18.09°C
# Thermostat 2 - Temperature: 22.54°C
# Thermostat 3 - Temperature: 23.83°C
#
#
# Thermostat 1 - Temperature: 24.63°C
# Thermostat 2 - Temperature: 24.88°C
# Thermostat 3 - Temperature: 21.72°C
#
#
# Thermostat 1 - Temperature: 27.32°C
# Thermostat 2 - Temperature: 20.56°C
# Thermostat 3 - Temperature: 23.04°C
#
#
# Thermostat 1 - Temperature: 25.86°C
# Thermostat 2 - Temperature: 25.47°C
# Thermostat 3 - Temperature: 21.77°C
#
#
# Thermostat 1 - Temperature: 20.48°C
# Thermostat 2 - Temperature: 24.96°C
# Thermostat 3 - Temperature: 25.39°C
#
#
# Thermostat 1 - Temperature: 19.38°C
# Thermostat 2 - Temperature: 18.60°C
# Thermostat 3 - Temperature: 27.46°C
#
#
# Thermostat 1 - Temperature: 23.63°C
# Thermostat 2 - Temperature: 18.51°C
# Thermostat 3 - Temperature: 22.30°C
#
#
# Thermostat 1 - Temperature: 18.65°C
# Thermostat 2 - Temperature: 18.35°C
# Thermostat 3 - Temperature: 20.61°C
#
#
# Thermostat 1 - Temperature: 19.07°C
# Thermostat 2 - Temperature: 25.10°C
# Thermostat 3 - Temperature: 21.54°C
#
#
# Thermostat 1 - Temperature: 22.02°C
# Thermostat 2 - Temperature: 23.65°C
# Thermostat 3 - Temperature: 23.96°C
#
#
# Thermostat 1 - Temperature: 20.92°C
# Thermostat 2 - Temperature: 21.76°C
# Thermostat 3 - Temperature: 19.87°C
#
#
# Thermostat 1 - Temperature: 19.13°C
# Thermostat 2 - Temperature: 23.08°C
# Thermostat 3 - Temperature: 17.33°C
#
#
# Thermostat 1 - Temperature: 21.32°C
# Thermostat 2 - Temperature: 20.93°C
# Thermostat 3 - Temperature: 20.09°C
#
#
# Thermostat 1 - Temperature: 21.17°C
# Thermostat 2 - Temperature: 19.17°C
# Thermostat 3 - Temperature: 26.15°C
#
#
# Thermostat 1 - Temperature: 18.25°C
# Thermostat 2 - Temperature: 20.49°C
# Thermostat 3 - Temperature: 25.11°C
#
#
# Thermostat 1 - Temperature: 23.48°C
# Thermostat 2 - Temperature: 18.03°C
# Thermostat 3 - Temperature: 25.32°C
#
#
# Thermostat 1 - Temperature: 23.87°C
# Thermostat 2 - Temperature: 24.09°C
# Thermostat 3 - Temperature: 20.03°C
#
#
# Thermostat 1 - Temperature: 23.70°C
# Thermostat 2 - Temperature: 26.48°C
# Thermostat 3 - Temperature: 19.13°C
#
#
# Thermostat 1 - Temperature: 18.55°C
# Thermostat 2 - Temperature: 18.95°C
# Thermostat 3 - Temperature: 19.27°C
#
#
# Thermostat 1 - Temperature: 21.69°C
# Thermostat 2 - Temperature: 21.57°C
# Thermostat 3 - Temperature: 20.90°C
#
#
# Thermostat 1 - Temperature: 24.96°C
# Thermostat 2 - Temperature: 21.51°C
# Thermostat 3 - Temperature: 19.97°C
#
#
# Thermostat 1 - Temperature: 17.65°C
# Thermostat 2 - Temperature: 21.76°C
# Thermostat 3 - Temperature: 22.57°C
#
#
# Thermostat 1 - Temperature: 21.61°C
# Thermostat 2 - Temperature: 25.47°C
# Thermostat 3 - Temperature: 21.51°C
#
#
# Thermostat 1 - Temperature: 25.50°C
# Thermostat 2 - Temperature: 17.88°C
# Thermostat 3 - Temperature: 25.80°C
#
#
# Thermostat 1 - Temperature: 26.28°C
# Thermostat 2 - Temperature: 18.66°C
# Thermostat 3 - Temperature: 21.95°C
#
#
# Thermostat 1 - Temperature: 23.51°C
# Thermostat 2 - Temperature: 18.62°C
# Thermostat 3 - Temperature: 24.98°C
#
#
# Thermostat 1 - Temperature: 24.39°C
# Thermostat 2 - Temperature: 19.55°C
# Thermostat 3 - Temperature: 27.17°C
#
#
# Thermostat 1 - Temperature: 24.00°C
# Thermostat 2 - Temperature: 21.31°C
# Thermostat 3 - Temperature: 18.00°C
#
#
# Thermostat 1 - Temperature: 19.20°C
# Thermostat 2 - Temperature: 20.86°C
# Thermostat 3 - Temperature: 23.74°C
#
#
# Thermostat 1 - Temperature: 22.19°C
# Thermostat 2 - Temperature: 17.68°C
# Thermostat 3 - Temperature: 23.59°C
#
#
# Thermostat 1 - Temperature: 24.42°C
# Thermostat 2 - Temperature: 23.90°C
# Thermostat 3 - Temperature: 22.26°C
#
#
# Thermostat 1 - Temperature: 19.59°C
# Thermostat 2 - Temperature: 21.39°C
# Thermostat 3 - Temperature: 18.49°C
#
#
# Thermostat 1 - Temperature: 21.58°C
# Thermostat 2 - Temperature: 18.63°C
# Thermostat 3 - Temperature: 18.06°C
#
#
# Thermostat 1 - Temperature: 17.47°C
# Thermostat 2 - Temperature: 25.86°C
# Thermostat 3 - Temperature: 24.08°C
#
#
# Thermostat 1 - Temperature: 20.68°C
# Thermostat 2 - Temperature: 19.12°C
# Thermostat 3 - Temperature: 20.47°C
#
#
# Thermostat 1 - Temperature: 26.92°C
# Thermostat 2 - Temperature: 19.20°C
# Thermostat 3 - Temperature: 24.07°C
#
#
# Thermostat 1 - Temperature: 20.54°C
# Thermostat 2 - Temperature: 22.73°C
# Thermostat 3 - Temperature: 26.25°C
#
#
# Thermostat 1 - Temperature: 19.46°C
# Thermostat 2 - Temperature: 25.55°C
# Thermostat 3 - Temperature: 21.45°C
#
#
# Thermostat 1 - Temperature: 17.89°C
# Thermostat 2 - Temperature: 19.55°C
# Thermostat 3 - Temperature: 24.67°C
#
#
# Thermostat 1 - Temperature: 22.15°C
# Thermostat 2 - Temperature: 27.05°C
# Thermostat 3 - Temperature: 18.59°C
#
#
# Thermostat 1 - Temperature: 21.33°C
# Thermostat 2 - Temperature: 18.53°C
# Thermostat 3 - Temperature: 19.88°C
#
#
# Thermostat 1 - Temperature: 19.47°C
# Thermostat 2 - Temperature: 20.25°C
# Thermostat 3 - Temperature: 19.77°C
#
#
# Thermostat 1 - Temperature: 24.72°C
# Thermostat 2 - Temperature: 18.38°C
# Thermostat 3 - Temperature: 27.22°C
#
#
# Thermostat 1 - Temperature: 20.00°C
# Thermostat 2 - Temperature: 20.98°C
# Thermostat 3 - Temperature: 26.22°C
#
#
# Thermostat 1 - Temperature: 19.24°C
# Thermostat 2 - Temperature: 26.70°C
# Thermostat 3 - Temperature: 18.76°C
#
#
# Thermostat 1 - Temperature: 26.88°C
# Thermostat 2 - Temperature: 18.89°C
# Thermostat 3 - Temperature: 18.67°C
#
#
# Thermostat 1 - Temperature: 22.84°C
# Thermostat 2 - Temperature: 24.10°C
# Thermostat 3 - Temperature: 26.37°C
#
#
# Thermostat 1 - Temperature: 20.54°C
# Thermostat 2 - Temperature: 19.64°C
# Thermostat 3 - Temperature: 22.24°C
#
#
# Thermostat 1 - Temperature: 24.28°C
# Thermostat 2 - Temperature: 20.34°C
# Thermostat 3 - Temperature: 23.70°C
#
#
# Thermostat 1 - Temperature: 22.64°C
# Thermostat 2 - Temperature: 22.59°C
# Thermostat 3 - Temperature: 23.45°C
#
#
# Thermostat 1 - Temperature: 26.99°C
# Thermostat 2 - Temperature: 23.66°C
# Thermostat 3 - Temperature: 18.22°C
#
#
# Thermostat 1 - Temperature: 26.93°C
# Thermostat 2 - Temperature: 19.22°C
# Thermostat 3 - Temperature: 25.48°C
#
#
# Thermostat 1 - Temperature: 21.05°C
# Thermostat 2 - Temperature: 19.90°C
# Thermostat 3 - Temperature: 26.70°C
#
#
# Thermostat 1 - Temperature: 22.87°C
# Thermostat 2 - Temperature: 26.75°C
# Thermostat 3 - Temperature: 25.20°C
#
#
# Thermostat 1 - Temperature: 23.93°C
# Thermostat 2 - Temperature: 22.81°C
# Thermostat 3 - Temperature: 21.21°C
#
#
# Thermostat 1 - Temperature: 26.77°C
# Thermostat 2 - Temperature: 26.41°C
# Thermostat 3 - Temperature: 18.55°C
#
#
# Thermostat 1 - Temperature: 23.99°C
# Thermostat 2 - Temperature: 26.57°C
# Thermostat 3 - Temperature: 25.66°C
#
#
# Thermostat 1 - Temperature: 20.22°C
# Thermostat 2 - Temperature: 22.77°C
# Thermostat 3 - Temperature: 18.38°C
#
#
# Thermostat 1 - Temperature: 25.33°C
# Thermostat 2 - Temperature: 24.39°C
# Thermostat 3 - Temperature: 18.20°C
#
#
# Thermostat 1 - Temperature: 23.01°C
# Thermostat 2 - Temperature: 23.28°C
# Thermostat 3 - Temperature: 21.80°C
#
#
# Thermostat 1 - Temperature: 26.75°C
# Thermostat 2 - Temperature: 22.23°C
# Thermostat 3 - Temperature: 24.71°C
#
#
# Thermostat 1 - Temperature: 18.33°C
# Thermostat 2 - Temperature: 19.19°C
# Thermostat 3 - Temperature: 20.56°C
#
#
# Thermostat 1 - Temperature: 19.74°C
# Thermostat 2 - Temperature: 19.73°C
# Thermostat 3 - Temperature: 25.26°C
#
#
# Thermostat 1 - Temperature: 26.08°C
# Thermostat 2 - Temperature: 22.32°C
# Thermostat 3 - Temperature: 25.41°C
#
#
# Thermostat 1 - Temperature: 20.73°C
# Thermostat 2 - Temperature: 21.76°C
# Thermostat 3 - Temperature: 25.26°C
#
#
# Thermostat 1 - Temperature: 24.97°C
# Thermostat 2 - Temperature: 23.14°C
# Thermostat 3 - Temperature: 22.94°C
#
#
# Thermostat 1 - Temperature: 25.23°C
# Thermostat 2 - Temperature: 17.79°C
# Thermostat 3 - Temperature: 24.55°C
#
#
# Thermostat 1 - Temperature: 24.76°C
# Thermostat 2 - Temperature: 22.99°C
# Thermostat 3 - Temperature: 20.31°C
#
#
# Thermostat 1 - Temperature: 24.15°C
# Thermostat 2 - Temperature: 18.47°C
# Thermostat 3 - Temperature: 20.04°C
#
#
# Thermostat 1 - Temperature: 22.80°C
# Thermostat 2 - Temperature: 21.16°C
# Thermostat 3 - Temperature: 21.79°C
# Thermostat 1 - Temperature: 24.58°C
# Thermostat 2 - Temperature: 19.54°C
# Thermostat 3 - Temperature: 18.03°C
#
#
# Thermostat 1 - Temperature: 24.37°C
# Thermostat 2 - Temperature: 26.21°C
# Thermostat 3 - Temperature: 19.39°C
#
#
# Thermostat 1 - Temperature: 19.80°C
# Thermostat 2 - Temperature: 26.97°C
# Thermostat 3 - Temperature: 23.03°C
#
#
# Thermostat 1 - Temperature: 21.23°C
# Thermostat 2 - Temperature: 21.35°C
# Thermostat 3 - Temperature: 19.72°C
#
#
# Thermostat 1 - Temperature: 22.78°C
# Thermostat 2 - Temperature: 21.92°C
# Thermostat 3 - Temperature: 22.20°C
#
#
# Thermostat 1 - Temperature: 26.58°C
# Thermostat 2 - Temperature: 18.57°C
# Thermostat 3 - Temperature: 23.59°C
#
#
# Thermostat 1 - Temperature: 24.75°C
# Thermostat 2 - Temperature: 26.10°C
# Thermostat 3 - Temperature: 22.41°C
#
#
# Thermostat 1 - Temperature: 20.48°C
# Thermostat 2 - Temperature: 17.59°C
# Thermostat 3 - Temperature: 20.93°C
#
#
# Thermostat 1 - Temperature: 26.06°C
# Thermostat 2 - Temperature: 22.66°C
# Thermostat 3 - Temperature: 20.11°C
#
#
# Thermostat 1 - Temperature: 18.88°C
# Thermostat 2 - Temperature: 20.51°C
# Thermostat 3 - Temperature: 18.78°C
#
#
# Thermostat 1 - Temperature: 21.10°C
# Thermostat 2 - Temperature: 24.73°C
# Thermostat 3 - Temperature: 26.58°C
#
#
# Thermostat 1 - Temperature: 20.78°C
# Thermostat 2 - Temperature: 19.20°C
# Thermostat 3 - Temperature: 24.74°C
#
#
# Thermostat 1 - Temperature: 18.27°C
# Thermostat 2 - Temperature: 18.96°C
# Thermostat 3 - Temperature: 24.60°C
#
#
# Thermostat 1 - Temperature: 22.96°C
# Thermostat 2 - Temperature: 21.61°C
# Thermostat 3 - Temperature: 22.64°C
#
#
# Thermostat 1 - Temperature: 26.78°C
# Thermostat 2 - Temperature: 18.84°C
# Thermostat 3 - Temperature: 27.01°C
#
#
# Thermostat 1 - Temperature: 19.49°C
# Thermostat 2 - Temperature: 18.74°C
# Thermostat 3 - Temperature: 24.17°C
#
#
# Thermostat 1 - Temperature: 19.06°C
# Thermostat 2 - Temperature: 26.68°C
# Thermostat 3 - Temperature: 17.39°C
#
#
# Thermostat 1 - Temperature: 21.56°C
# Thermostat 2 - Temperature: 26.17°C
# Thermostat 3 - Temperature: 22.43°C
#
#
# Thermostat 1 - Temperature: 26.72°C
# Thermostat 2 - Temperature: 18.76°C
# Thermostat 3 - Temperature: 24.26°C
#
#
# Thermostat 1 - Temperature: 26.47°C
# Thermostat 2 - Temperature: 23.10°C
# Thermostat 3 - Temperature: 25.83°C
#
#
# Thermostat 1 - Temperature: 23.44°C
# Thermostat 2 - Temperature: 22.66°C
# Thermostat 3 - Temperature: 24.26°C
#
#
# Thermostat 1 - Temperature: 24.64°C
# Thermostat 2 - Temperature: 19.78°C
# Thermostat 3 - Temperature: 23.99°C
#
#
# Thermostat 1 - Temperature: 21.31°C
# Thermostat 2 - Temperature: 26.58°C
# Thermostat 3 - Temperature: 19.22°C
#
#
# Thermostat 1 - Temperature: 24.94°C
# Thermostat 2 - Temperature: 26.39°C
# Thermostat 3 - Temperature: 24.70°C
#
#
# Thermostat 1 - Temperature: 21.17°C
# Thermostat 2 - Temperature: 26.20°C
# Thermostat 3 - Temperature: 22.43°C
#
#
# Thermostat 1 - Temperature: 26.72°C
# Thermostat 2 - Temperature: 22.61°C
# Thermostat 3 - Temperature: 22.45°C
#
#
# Thermostat 1 - Temperature: 23.16°C
# Thermostat 2 - Temperature: 23.70°C
# Thermostat 3 - Temperature: 20.89°C
#
#
# Thermostat 1 - Temperature: 20.02°C
# Thermostat 2 - Temperature: 19.60°C
# Thermostat 3 - Temperature: 25.57°C
#
#
# Thermostat 1 - Temperature: 25.03°C
# Thermostat 2 - Temperature: 21.65°C
# Thermostat 3 - Temperature: 23.38°C
#
#
# Thermostat 1 - Temperature: 18.86°C
# Thermostat 2 - Temperature: 21.19°C
# Thermostat 3 - Temperature: 25.68°C
#
#
# Thermostat 1 - Temperature: 25.74°C
# Thermostat 2 - Temperature: 26.81°C
# Thermostat 3 - Temperature: 23.12°C
#
#
# Thermostat 1 - Temperature: 21.94°C
# Thermostat 2 - Temperature: 20.62°C
# Thermostat 3 - Temperature: 23.74°C
#
#
# Thermostat 1 - Temperature: 24.22°C
# Thermostat 2 - Temperature: 23.13°C
# Thermostat 3 - Temperature: 20.33°C
#
#
# Thermostat 1 - Temperature: 24.02°C
# Thermostat 2 - Temperature: 23.08°C
# Thermostat 3 - Temperature: 24.58°C
#
#
# Thermostat 1 - Temperature: 17.92°C
# Thermostat 2 - Temperature: 24.25°C
# Thermostat 3 - Temperature: 19.95°C
#
#
# Thermostat 1 - Temperature: 21.29°C
# Thermostat 2 - Temperature: 19.80°C
# Thermostat 3 - Temperature: 23.68°C
#
#
# Thermostat 1 - Temperature: 21.99°C
# Thermostat 2 - Temperature: 24.01°C
# Thermostat 3 - Temperature: 22.97°C
#
#
# Thermostat 1 - Temperature: 24.66°C
# Thermostat 2 - Temperature: 19.53°C
# Thermostat 3 - Temperature: 18.60°C
#
#
# Thermostat 1 - Temperature: 22.87°C
# Thermostat 2 - Temperature: 22.42°C
# Thermostat 3 - Temperature: 18.13°C
#
#
# Thermostat 1 - Temperature: 23.31°C
# Thermostat 2 - Temperature: 17.62°C
# Thermostat 3 - Temperature: 24.30°C
#
#
# Thermostat 1 - Temperature: 27.11°C
# Thermostat 2 - Temperature: 24.36°C
# Thermostat 3 - Temperature: 19.70°C
#
#
# Thermostat 1 - Temperature: 22.04°C
# Thermostat 2 - Temperature: 22.51°C
# Thermostat 3 - Temperature: 20.24°C
#
#
# Thermostat 1 - Temperature: 24.44°C
# Thermostat 2 - Temperature: 18.38°C
# Thermostat 3 - Temperature: 21.19°C
#
#
# Thermostat 1 - Temperature: 25.03°C
# Thermostat 2 - Temperature: 24.47°C
# Thermostat 3 - Temperature: 18.44°C
#
#
# Thermostat 1 - Temperature: 26.77°C
# Thermostat 2 - Temperature: 20.02°C
# Thermostat 3 - Temperature: 25.27°C
#
#
# Thermostat 1 - Temperature: 25.23°C
# Thermostat 2 - Temperature: 23.68°C
# Thermostat 3 - Temperature: 18.04°C

# %%
# MySQL database settings
db_host = "localhost"
db_user = "root"
db_password = "Shiphrah07"
db_name = "stock"


# Kafka settings
kafka_broker = "localhost:9092"
kafka_topic = "temperature_readings"

# %%
import random
import time
import requests
from datetime import datetime
import pandas as pd
from sqlalchemy import create_engine
from kafka import KafkaProducer

# OpenWeatherMap API settings
api_key = "6156d68254dfe8638575e65ff5c9d4f2"
weather_api_url = "http://api.openweathermap.org/data/2.5/weather"
city = "New York"
units = "metric"

# MySQL database settings
db_host = "localhost"
db_user = "root"
db_password = "Shiphrah07"
db_name = "stock"


# Kafka settings
kafka_broker = "localhost:9092"
kafka_topic = "temperature_readings"
# Simulated thermostat configuration
num_thermostats = 3

def generate_temperature(weather_data):
    base_temperature = 20.0
    temperature_range = 5.0
    weather_temperature = weather_data["main"]["temp"]
    return base_temperature + random.uniform(-temperature_range, temperature_range) + (weather_temperature - 20.0)

def get_weather_data():
    params = {
        "q": city,
        "units": units,
        "appid": api_key
    }
    try:
        response = requests.get(weather_api_url, params=params)
        response.raise_for_status()  # Raise an exception if request fails
        return response.json()
    except requests.exceptions.RequestException as e:
        print("Failed to fetch weather data:", e)
        return None

# Create Kafka producer
producer = KafkaProducer(bootstrap_servers=kafka_broker)

# Create MySQL engine
db_url = f"mysql+mysqlconnector://{db_user}:{db_password}@{db_host}/{db_name}"
engine = create_engine(db_url)

# Initialize DataFrame
columns = ["Timestamp", "Thermostat_ID", "Temperature"]
data = []

while True:
    weather_data = get_weather_data()
    if weather_data:
        for thermostat_id in range(1, num_thermostats + 1):
            temperature = generate_temperature(weather_data)
            timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            
            # Add data to DataFrame
            data.append([timestamp, thermostat_id, temperature])
            
            # Send data to Kafka topic
            kafka_data = f"{timestamp},{thermostat_id},{temperature}"
            producer.send(kafka_topic, value=kafka_data.encode("utf-8"))
            
            # Sleep for a short interval before sending next data
            time.sleep(1)
            
    else:
        print("Failed to fetch weather data")
    
    # Convert data to DataFrame and store in MySQL
    if data:
        df = pd.DataFrame(data, columns=columns)
        df.to_sql("temperature_data", con=engine, if_exists="append", index=False)
        print("Data stored in MySQL and sent to Kafka")
        data = []  # Clear data list
    
    time.sleep(3)  # Fetch data every 5 minutes
# Out:
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
# Data stored in MySQL and sent to Kafka
